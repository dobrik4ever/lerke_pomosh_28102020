# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
left, right = 361, 363
df = pd.read_csv('data_0.csv',sep='\t')
data = df.loc[(df['Wavelength[nm]']>left) & (df['Wavelength[nm]']<right)]
lines = []
for line in data.columns:
    if line not in 'Wavelength[nm]':
        if data[line].max() > 900:
            lines.append(array(data[line]))

for line in lines:
    plot(line)


print(len(lines))
# Out:
# 10

# %%
def approx(xx, yy):
    from scipy.optimize import curve_fit
    def func(x, s, mu, c):
        return (1.0/(s*sqrt(2*pi)))*e**(-0.5*((x-mu)/s)**2) + c
    xr = xx
    yr = yy
    plot(xr,yr,'.-')
    ymaxi = yr.argmax()
    a = 3
    yr = yr[ymaxi-a:ymaxi+a+1]
    xr = xr[ymaxi-a:ymaxi+a+1]
    # popt, pcov = curve_fit(func, xr, yr, p0=[1,ymaxi,0])#, bounds=([0,5,0],[1000,15,1000]))
    scatter(xr,yr,c='r')
    f = polyfit(xr,yr,10)
    x = linspace(7,xx.shape[0]-10,100)
    y = poly1d(f)(x)
    plot(x, y)

# %%
x = arange(0,len(lines[0])).astype(float64)
# x -= x[-1]/2
y = lines[0]

ymin = y.min()
y -= y.min()
ymax = y.max()
y /= ymax
# xr = arange(0,10)
# yr = func(xr, 2, 3)
# yr = yr + random.random(xr.shape)*0.05
approx(x,y)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:12: RankWarning: Polyfit may be poorly conditioned
#   if sys.path[0] == '':

# %% [markdown]
# \begin{equation}
# f(\sigma,x) = \frac{1}{\sigma \sqrt{2 \pi}}e^{-\frac{1}{2}(\frac{x-\mu}{\sigma})^2}
# \end{equation}

# %%
popt
